# %%
import numpy as np
import matplotlib.pyplot as plt

SMALL_SIZE = 16
MEDIUM_SIZE = 18
BIGGER_SIZE = 22
plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=SMALL_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=MEDIUM_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title

# %%
def monte_circle(x_rand, y_rand, N, SQUARE_LENGTH):
    n_inside_circle = sum(circ_y(x_monte) > y_monte)  # random y is inside of circle 
    fraction = n_inside_circle / N
    
    
    square_area = SQUARE_LENGTH**2
    
    radius_circle = SQUARE_LENGTH
    circle_area_quarter  = square_area*fraction
    entire_circle = circle_area_quarter * 4
    pi = entire_circle / radius_circle**2
    
    
    absolute_relative_err = np.abs((pi - np.pi)/pi *100)
    print(f'Area of Circle with Radius: {radius_circle} = {entire_circle}')
    print(f'\nAbsolute Percentage Error = {absolute_relative_err:.2f} %')
    return pi

def monte_plot(x_monte, y_monte,pi_est ,subsample=500):
    unique_random_id = np.unique(np.random.randint(0, N, size=subsample))

    x_monte_subsample = x_monte[unique_random_id]
    y_monte_subsample = y_monte[unique_random_id]

    inside_mask = circ_y(x_monte_subsample) > y_monte_subsample

    x_inside = x_monte_subsample[inside_mask]
    y_inside = y_monte_subsample[inside_mask]

    x_outside = x_monte_subsample[~inside_mask]
    y_outside = y_monte_subsample[~inside_mask]

    fig, axe = plt.subplots(figsize=(8,8))
    plt.plot(domain, circ_y(domain), linewidth=2, color='k')
    axe.fill_between(domain, 0, circ_y(domain)) # fill area
    plt.scatter(x_inside, y_inside, label='Inside Quarter Circle')
    plt.scatter(x_outside, y_outside, label='Outside Quarter Circle')
    plt.xlim(0,1.0)
    plt.ylim(0,1.0)
    plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.);
    plt.title(r'Monte Carlo Quarter Circle: $\pi$ Estimation = ' + f'{pi_est}')

# %%
SQUARE_LENGTH = 1
domain=np.linspace(0,SQUARE_LENGTH,101)

circ_y = lambda x: np.sqrt(1-x**2)   

fig, axe = plt.subplots(figsize=(8,8))
plt.plot(domain, circ_y(domain), linewidth=2, color='k')
axe.fill_between(domain, 0, circ_y(domain)) # fill area
plt.xlim(0,1.0)
plt.ylim(0,1.0)
plt.title('Quarter Circle')
# Out:
# Text(0.5, 1.0, 'Quarter Circle')

# %%
N = 100_000
x_monte, y_monte = np.random.random(N), np.random.random(N)

# %%
est_pi = monte_circle(x_monte, y_monte,N, SQUARE_LENGTH )
# Out:
# Area of Circle with Radius: 1 = 3.136
#
# Absolute Percentage Error = 0.18 %

# %%
monte_plot(x_monte, y_monte, est_pi)
